# %% [markdown]
# <a href="https://colab.research.google.com/github/t-abs/Machine-Learning/blob/main/One_hot_encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# *Target is to convert the text to numeric data*

# %%
df=pd.read_csv("/content/homeprices (1).csv")

# %%
df
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
dummies=pd.get_dummies(df.town)

# %%
dummies
# Out:
#     monroe township  robinsville  west windsor
# 0                 1            0             0
# 1                 1            0             0
# 2                 1            0             0
# 3                 1            0             0
# 4                 1            0             0
# 5                 0            0             1
# 6                 0            0             1
# 7                 0            0             1
# 8                 0            0             1
# 9                 0            1             0
# 10                0            1             0
# 11                0            1             0
# 12                0            1             0

# %%
merged=pd.concat([df,dummies],axis='columns')
merged
# Out:
#                town  area   price  monroe township  robinsville  west windsor
# 0   monroe township  2600  550000                1            0             0
# 1   monroe township  3000  565000                1            0             0
# 2   monroe township  3200  610000                1            0             0
# 3   monroe township  3600  680000                1            0             0
# 4   monroe township  4000  725000                1            0             0
# 5      west windsor  2600  585000                0            0             1
# 6      west windsor  2800  615000                0            0             1
# 7      west windsor  3300  650000                0            0             1
# 8      west windsor  3600  710000                0            0             1
# 9       robinsville  2600  575000                0            1             0
# 10      robinsville  2900  600000                0            1             0
# ...

# %%
data=merged.drop(['town','west windsor'],axis='columns')
data
# Out:
#     area   price  monroe township  robinsville
# 0   2600  550000                1            0
# 1   3000  565000                1            0
# 2   3200  610000                1            0
# 3   3600  680000                1            0
# 4   4000  725000                1            0
# 5   2600  585000                0            0
# 6   2800  615000                0            0
# 7   3300  650000                0            0
# 8   3600  710000                0            0
# 9   2600  575000                0            1
# 10  2900  600000                0            1
# 11  3100  620000                0            1
# 12  3600  695000                0            1

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
X=data.drop('price',axis='columns')
X
# Out:
#     area  monroe township  robinsville
# 0   2600                1            0
# 1   3000                1            0
# 2   3200                1            0
# 3   3600                1            0
# 4   4000                1            0
# 5   2600                0            0
# 6   2800                0            0
# 7   3300                0            0
# 8   3600                0            0
# 9   2600                0            1
# 10  2900                0            1
# 11  3100                0            1
# 12  3600                0            1

# %%
y=data.price

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[2880,0,1]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([600927.43496023])

# %%
model.score(X,y)
# Out:
# 0.9573929037221872

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
dfle = df
dfle.town = le.fit_transform(dfle.town)
dfle
# Out:
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %%
X = dfle[['town','area']].values

# %%
X
# Out:
# array([[   0, 2600],
#        [   0, 3000],
#        [   0, 3200],
#        [   0, 3600],
#        [   0, 4000],
#        [   2, 2600],
#        [   2, 2800],
#        [   2, 3300],
#        [   2, 3600],
#        [   1, 2600],
#        [   1, 2900],
#        [   1, 3100],
#        [   1, 3600]])

# %%
y = dfle.price.values
y
# Out:
# array([550000, 565000, 610000, 680000, 725000, 585000, 615000, 650000,
#        710000, 575000, 600000, 620000, 695000])

# %% [markdown]
# Exercise

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/content/carprices.csv")

# %%
data.head()
# Out:
#   Car Model  Mileage  Sell Price($)  Age(yrs)
# 0    BMW X5    69000          18000         6
# 1    BMW X5    35000          34000         3
# 2    BMW X5    57000          26100         5
# 3    BMW X5    22500          40000         2
# 4    BMW X5    46000          31500         4

# %%
dummies=pd.get_dummies(data['Car Model'])

# %%
dummies
# Out:
#     Audi A5  BMW X5  Mercedez Benz C class
# 0         0       1                      0
# 1         0       1                      0
# 2         0       1                      0
# 3         0       1                      0
# 4         0       1                      0
# 5         1       0                      0
# 6         1       0                      0
# 7         1       0                      0
# 8         1       0                      0
# 9         0       0                      1
# 10        0       0                      1
# 11        0       0                      1
# 12        0       0                      1

# %%
merged = pd.concat([df,dummies],axis='columns')
merged
# Out:
#     town  area   price  Audi A5  BMW X5  Mercedez Benz C class
# 0      0  2600  550000        0       1                      0
# 1      0  3000  565000        0       1                      0
# 2      0  3200  610000        0       1                      0
# 3      0  3600  680000        0       1                      0
# 4      0  4000  725000        0       1                      0
# 5      2  2600  585000        1       0                      0
# 6      2  2800  615000        1       0                      0
# 7      2  3300  650000        1       0                      0
# 8      2  3600  710000        1       0                      0
# 9      1  2600  575000        0       0                      1
# 10     1  2900  600000        0       0                      1
# 11     1  3100  620000        0       0                      1
# 12     1  3600  695000        0       0                      1

# %%
x = merged.drop(["Mercedez Benz C class"],axis='columns')
x
# Out:
#     town  area   price  Audi A5  BMW X5
# 0      0  2600  550000        0       1
# 1      0  3000  565000        0       1
# 2      0  3200  610000        0       1
# 3      0  3600  680000        0       1
# 4      0  4000  725000        0       1
# 5      2  2600  585000        1       0
# 6      2  2800  615000        1       0
# 7      2  3300  650000        1       0
# 8      2  3600  710000        1       0
# 9      1  2600  575000        0       0
# 10     1  2900  600000        0       0
# 11     1  3100  620000        0       0
# 12     1  3600  695000        0       0

# %%
y=merged.price
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.predict([[0,2500,50000,0,0]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([50000.])

# %%
lr.score(x,y)
# Out:
# 1.0
