# %% [markdown]
# <a href="https://colab.research.google.com/github/t-abs/Machine-Learning/blob/main/BostonHousing_DecisionTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/content/BostonHousing.csv")

# %%
data.head(10)
# Out:
#       crim    zn  indus  chas    nox     rm    age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# ...

# %%
data.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
x=data.drop(columns='rad',axis=1)
y=data['rad']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model.predict(x_train)

# %%
y_pred
# Out:
# array([24,  6,  4, 24,  3,  5,  5,  1,  5,  4,  6, 24,  5,  7,  4, 24,  3,
#         5,  5,  5, 24, 24,  4,  5, 24, 24,  1, 24, 24,  4,  4,  1, 24,  1,
#         6,  4,  4,  3, 24,  4,  4,  8, 24, 24,  2, 24,  3,  7,  4,  4,  8,
#         5, 24, 24,  3, 24,  3,  4,  4,  5,  4,  1,  1, 24,  2,  1, 24,  5,
#         5,  4,  4, 24,  5, 24,  8,  2,  2,  4,  4,  4,  5,  4,  5,  4, 24,
#         1,  7,  5,  2,  2,  4, 24,  4,  5,  5,  3,  4,  4,  4,  4,  4, 24,
#        24,  7,  6,  5,  6,  2,  5,  4,  5,  4, 24,  4, 24,  5,  1,  2,  4,
#         3,  5,  3,  4, 24,  4,  5,  5, 24, 24,  4,  5,  5, 24,  4,  5,  8,
#         5,  5, 24,  3,  7, 24,  4, 24,  4,  2,  7,  4,  5,  5,  1,  8,  8,
#         5,  3,  5,  5, 24,  4,  5,  5,  5,  6,  6, 24,  4,  4,  2,  3,  5,
#         6,  6,  2,  5,  5,  5,  4,  8,  3,  4,  5,  5,  4,  4, 24,  5, 24,
#        24,  4,  4,  5,  5,  3,  7,  3,  8,  4, 24,  5,  5,  8,  7,  8,  8,
# ...

# %%
from sklearn import tree
plt.figure(figsize=(20,20))
tree.plot_tree(model,filled=True)
# Out:
# [Text(0.38386587078651685, 0.9666666666666667, 'x[0] <= 3.552\ngini = 0.82\nsamples = 379\nvalue = [19, 18, 24, 83, 85, 19, 14, 19, 98]'),
#  Text(0.27089185393258425, 0.9, 'x[9] <= 15.25\ngini = 0.799\nsamples = 283\nvalue = [19, 18, 24, 83, 84, 19, 14, 19, 3]'),
#  Text(0.11235955056179775, 0.8333333333333334, 'x[2] <= 2.135\ngini = 0.194\nsamples = 57\nvalue = [1, 4, 0, 1, 51, 0, 0, 0, 0]'),
#  Text(0.0898876404494382, 0.7666666666666667, 'x[8] <= 292.5\ngini = 0.612\nsamples = 7\nvalue = [1, 4, 0, 1, 1, 0, 0, 0, 0]'),
#  Text(0.06741573033707865, 0.7, 'x[3] <= 0.5\ngini = 0.667\nsamples = 3\nvalue = [1, 0, 0, 1, 1, 0, 0, 0, 0]'),
#  Text(0.0449438202247191, 0.6333333333333333, 'x[11] <= 3.46\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0, 0, 0, 0]'),
#  Text(0.02247191011235955, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0, 0, 0]'),
#  Text(0.06741573033707865, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0, 0, 0]'),
# ...
