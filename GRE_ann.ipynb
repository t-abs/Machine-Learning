# %% [markdown]
# <a href="https://colab.research.google.com/github/t-abs/Machine-Learning/blob/main/GRE_ann.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/admission_data.csv")

# %%
df.head(10)
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
# 5        330          115                  5  4.5   3.0  9.34         1
# 6        321          109                  3  3.0   4.0  8.20         1
# 7        308          101                  2  3.0   4.0  7.90         0
# 8        302          102                  1  2.0   1.5  8.00         0
# 9        323          108                  3  3.5   3.0  8.60         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65
# 5              0.90
# 6              0.75
# ...

# %%
df.shape
# Out:
# (500, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          500 non-null    int64
#  1   TOEFL Score        500 non-null    int64
#  2   University Rating  500 non-null    int64
#  3   SOP                500 non-null    float64
#  4   LOR                500 non-null    float64
#  5   CGPA               500 non-null    float64
#  6   Research           500 non-null    int64
#  7   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 31.4 KB

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
x=df.iloc[:,0:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
# [500 rows x 7 columns]

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit , Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x_train
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 238        310          104                  3  2.0   3.5  8.37         0
# 438        318          110                  1  2.5   3.5  8.54         1
# 475        300          101                  3  3.5   2.5  7.88         0
# 58         300           99                  1  3.0   2.0  6.80         1
# 380        322          104                  3  3.5   4.0  8.84         1
# ..         ...          ...                ...  ...   ...   ...       ...
# 255        307          110                  4  4.0   4.5  8.37         0
# 72         321          111                  5  5.0   5.0  9.45         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 235        326          111                  5  4.5   4.0  9.23         1
# 37         300          105                  1  1.0   2.0  7.80         0
#
# [400 rows x 7 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
x_test_scaled
# Out:
# array([[ 0.46      ,  0.5       ,  0.25      ,  0.375     ,  0.14285714,
#          0.5224359 ,  0.        ],
#        [ 0.44      ,  0.53571429,  0.5       ,  0.5       ,  0.42857143,
#          0.53205128,  1.        ],
#        [ 0.98      ,  0.96428571,  1.        ,  0.875     ,  0.71428571,
#          0.92948718,  0.        ],
#        [ 0.52      ,  0.53571429,  0.25      ,  0.625     ,  0.57142857,
#          0.58974359,  1.        ],
#        [ 0.7       ,  0.64285714,  0.75      ,  0.875     ,  0.71428571,
#          0.69230769,  1.        ],
#        [ 0.42      ,  0.32142857,  0.25      ,  0.375     ,  0.57142857,
#          0.49358974,  1.        ],
#        [ 0.6       ,  0.42857143,  0.5       ,  0.5       ,  0.57142857,
#          0.62179487,  1.        ],
#        [ 0.74      ,  0.39285714,  0.5       ,  0.75      ,  0.71428571,
#          0.48076923,  1.        ],
#        [ 0.62      ,  0.67857143,  0.5       ,  0.625     ,  0.71428571,
# ...

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(7,activation='relu',input_dim=7))
model.add(Dense(7,activation='relu'))
model.add(Dense(1,activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 7)                 56
#
#  dense_3 (Dense)             (None, 7)                 56
#
#  dense_4 (Dense)             (None, 1)                 8
#
# ...
# Total params: 120 (480.00 Byte)
# Trainable params: 120 (480.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error',optimizer='Adam')

# %%
history=model.fit(x_train_scaled,y_train,epochs=50,validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 2/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 3/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 4/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0091 - val_loss: 0.0093
# Epoch 5/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0092
# Epoch 6/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 7/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0086 - val_loss: 0.0089
# Epoch 8/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0085 - val_loss: 0.0087
# Epoch 9/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0083 - val_loss: 0.0086
# Epoch 10/50
# ...

# %%
y_pred=model.predict(x_test_scaled)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.705875792367435
