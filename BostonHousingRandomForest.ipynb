# %% [markdown]
# <a href="https://colab.research.google.com/github/t-abs/Machine-Learning/blob/main/BostonHousingRandomForest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/BostonHousing.csv")

# %%
data.head(10)
# Out:
#       crim    zn  indus  chas    nox     rm    age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2
# 5  394.12   5.21  28.7
# 6  395.60  12.43  22.9
# 7  396.90  19.15  27.1
# 8  386.63  29.93  16.5
# 9  386.71  17.10  18.9

# %%
x=data.drop(columns='rad',axis=1)
y=data['rad']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model.score(x_test,y_test)
# Out:
# 0.968503937007874

# %%
model.predict(x_test)
# Out:
# array([ 5,  2, 24,  5,  4,  4,  5,  5,  5, 24,  6,  5,  7,  6,  4,  6, 24,
#         5,  2,  4, 24,  3,  1,  5,  5,  5,  2,  4,  5,  5, 24, 24,  5,  5,
#         4,  4, 24,  4,  7, 24,  4,  5,  2,  4, 24, 24,  4,  3,  4,  4,  7,
#         4, 24,  6, 24,  5,  4, 24,  2,  3,  4, 24, 24,  4, 24,  4, 24,  3,
#        24,  8,  6, 24,  5,  1, 24,  4,  3,  6,  4,  5,  5,  2, 24,  8,  6,
#        24,  5,  1,  2,  4,  3,  7,  6, 24,  4,  1,  5,  8,  7, 24,  3,  5,
#         5,  4,  3, 24,  6,  5,  5, 24,  4,  1, 24,  4, 24,  3,  4,  2,  3,
#        24,  8,  8,  3, 24,  4, 24,  5])

# %%
from sklearn import tree
plt.figure(figsize=(15,15))
tree.plot_tree(model.estimators_[0],filled=True)
# Out:
# [Text(0.7171875, 0.96875, 'x[0] <= 3.604\ngini = 0.808\nsamples = 237\nvalue = [17, 20, 23, 83, 93, 13, 10, 19, 101]'),
#  Text(0.6990056818181818, 0.90625, 'x[8] <= 407.0\ngini = 0.777\nsamples = 181\nvalue = [17, 20, 23, 83, 93, 13, 10, 19, 1]'),
#  Text(0.4889204545454545, 0.84375, 'x[4] <= 0.595\ngini = 0.775\nsamples = 162\nvalue = [16, 20, 23, 62, 93, 8, 10, 19, 0]'),
#  Text(0.4707386363636364, 0.78125, 'x[7] <= 3.514\ngini = 0.81\nsamples = 140\nvalue = [16, 20, 23, 62, 57, 8, 10, 19, 0]'),
#  Text(0.17727272727272728, 0.71875, 'x[9] <= 20.95\ngini = 0.833\nsamples = 35\nvalue = [8, 14, 1, 5, 11, 6, 3, 6, 0]'),
#  Text(0.1590909090909091, 0.65625, 'x[8] <= 286.0\ngini = 0.8\nsamples = 30\nvalue = [0, 14, 1, 5, 11, 6, 3, 6, 0]'),
#  Text(0.07272727272727272, 0.59375, 'x[2] <= 2.675\ngini = 0.475\nsamples = 12\nvalue = [0, 14, 1, 0, 2, 0, 3, 0, 0]'),
#  Text(0.03636363636363636, 0.53125, 'x[5] <= 7.002\ngini = 0.375\nsamples = 3\nvalue = [0, 0, 1, 0, 0, 0, 3, 0, 0]'),
#  Text(0.01818181818181818, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 3, 0, 0]'),
#  Text(0.05454545454545454, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0, 0, 0]'),
#  Text(0.10909090909090909, 0.53125, 'x[1] <= 10.0\ngini = 0.219\nsamples = 9\nvalue = [0, 14, 0, 0, 2, 0, 0, 0, 0]'),
#  Text(0.09090909090909091, 0.46875, 'x[9] <= 17.1\ngini = 0.124\nsamples = 8\nvalue = [0, 14, 0, 0, 1, 0, 0, 0, 0]'),
#  Text(0.07272727272727272, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0, 0, 0]'),
#  Text(0.10909090909090909, 0.40625, 'gini = 0.0\nsamples = 7\nvalue = [0, 14, 0, 0, 0, 0, 0, 0, 0]'),
#  Text(0.12727272727272726, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0, 0, 0]'),
#  Text(0.24545454545454545, 0.59375, 'x[10] <= 396.24\ngini = 0.737\nsamples = 18\nvalue = [0, 0, 0, 5, 9, 6, 0, 6, 0]'),
#  Text(0.2, 0.53125, 'x[0] <= 0.297\ngini = 0.56\nsamples = 12\nvalue = [0, 0, 0, 1, 9, 1, 0, 4, 0]'),
#  Text(0.16363636363636364, 0.46875, 'x[5] <= 5.765\ngini = 0.18\nsamples = 8\nvalue = [0, 0, 0, 0, 9, 1, 0, 0, 0]'),
#  Text(0.14545454545454545, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.18181818181818182, 0.40625, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 9, 0, 0, 0, 0]'),
#  Text(0.23636363636363636, 0.46875, 'x[10] <= 361.265\ngini = 0.32\nsamples = 4\nvalue = [0, 0, 0, 1, 0, 0, 0, 4, 0]'),
#  Text(0.21818181818181817, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0, 0, 0]'),
#  Text(0.2545454545454545, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 0, 0, 4, 0]'),
#  Text(0.2909090909090909, 0.53125, 'x[0] <= 0.391\ngini = 0.628\nsamples = 6\nvalue = [0, 0, 0, 4, 0, 5, 0, 2, 0]'),
#  Text(0.2727272727272727, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 5, 0, 0, 0]'),
#  Text(0.3090909090909091, 0.46875, 'x[2] <= 8.05\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 4, 0, 0, 0, 2, 0]'),
#  Text(0.2909090909090909, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 0, 2, 0]'),
#  Text(0.32727272727272727, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 4, 0, 0, 0, 0, 0]'),
#  Text(0.19545454545454546, 0.65625, 'gini = 0.0\nsamples = 5\nvalue = [8, 0, 0, 0, 0, 0, 0, 0, 0]'),
#  Text(0.7642045454545454, 0.71875, 'x[0] <= 0.363\ngini = 0.762\nsamples = 105\nvalue = [8, 6, 22, 57, 46, 2, 7, 13, 0]'),
#  Text(0.6920454545454545, 0.65625, 'x[4] <= 0.491\ngini = 0.759\nsamples = 88\nvalue = [8, 6, 22, 41, 46, 2, 7, 4, 0]'),
#  Text(0.6022727272727273, 0.59375, 'x[8] <= 355.0\ngini = 0.776\nsamples = 65\nvalue = [8, 6, 22, 37, 15, 2, 7, 3, 0]'),
#  Text(0.5840909090909091, 0.53125, 'x[4] <= 0.441\ngini = 0.744\nsamples = 57\nvalue = [8, 6, 22, 37, 4, 2, 7, 3, 0]'),
#  Text(0.4590909090909091, 0.46875, 'x[9] <= 15.8\ngini = 0.695\nsamples = 33\nvalue = [8, 5, 2, 26, 2, 2, 7, 0, 0]'),
#  Text(0.36363636363636365, 0.40625, 'x[4] <= 0.403\ngini = 0.625\nsamples = 8\nvalue = [6, 4, 0, 1, 1, 0, 0, 0, 0]'),
#  Text(0.34545454545454546, 0.34375, 'gini = 0.0\nsamples = 3\nvalue = [6, 0, 0, 0, 0, 0, 0, 0, 0]'),
#  Text(0.38181818181818183, 0.34375, 'x[1] <= 88.75\ngini = 0.5\nsamples = 5\nvalue = [0, 4, 0, 1, 1, 0, 0, 0, 0]'),
#  Text(0.36363636363636365, 0.28125, 'gini = 0.0\nsamples = 3\nvalue = [0, 4, 0, 0, 0, 0, 0, 0, 0]'),
#  Text(0.4, 0.28125, 'x[11] <= 3.88\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0, 0, 0, 0]'),
#  Text(0.38181818181818183, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0, 0, 0]'),
#  Text(0.41818181818181815, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0, 0, 0]'),
#  Text(0.5545454545454546, 0.40625, 'x[4] <= 0.43\ngini = 0.57\nsamples = 25\nvalue = [2, 1, 2, 25, 1, 2, 7, 0, 0]'),
#  Text(0.509090909090909, 0.34375, 'x[12] <= 29.35\ngini = 0.464\nsamples = 15\nvalue = [1, 1, 2, 18, 1, 2, 0, 0, 0]'),
#  Text(0.4727272727272727, 0.28125, 'x[4] <= 0.395\ngini = 0.318\nsamples = 12\nvalue = [1, 1, 0, 18, 0, 2, 0, 0, 0]'),
#  Text(0.45454545454545453, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0, 0, 0]'),
#  Text(0.4909090909090909, 0.21875, 'x[5] <= 6.309\ngini = 0.254\nsamples = 11\nvalue = [0, 1, 0, 18, 0, 2, 0, 0, 0]'),
#  Text(0.4727272727272727, 0.15625, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 14, 0, 0, 0, 0, 0]'),
#  Text(0.509090909090909, 0.15625, 'x[5] <= 6.449\ngini = 0.571\nsamples = 5\nvalue = [0, 1, 0, 4, 0, 2, 0, 0, 0]'),
#  Text(0.4909090909090909, 0.09375, 'x[8] <= 306.5\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 0, 0, 2, 0, 0, 0]'),
#  Text(0.4727272727272727, 0.03125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2, 0, 0, 0]'),
#  Text(0.509090909090909, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0, 0, 0]'),
#  Text(0.5272727272727272, 0.09375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 4, 0, 0, 0, 0, 0]'),
#  Text(0.5454545454545454, 0.28125, 'x[4] <= 0.41\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 0, 1, 0, 0, 0, 0]'),
#  Text(0.5272727272727272, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0, 0, 0]'),
#  Text(0.5636363636363636, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0, 0, 0, 0]'),
#  Text(0.6, 0.34375, 'x[4] <= 0.435\ngini = 0.56\nsamples = 10\nvalue = [1, 0, 0, 7, 0, 0, 7, 0, 0]'),
#  Text(0.5818181818181818, 0.28125, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 0, 0, 7, 0, 0]'),
#  Text(0.6181818181818182, 0.28125, 'x[8] <= 296.5\ngini = 0.219\nsamples = 5\nvalue = [1, 0, 0, 7, 0, 0, 0, 0, 0]'),
#  Text(0.6, 0.21875, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 7, 0, 0, 0, 0, 0]'),
#  Text(0.6363636363636364, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0, 0, 0]'),
#  Text(0.7090909090909091, 0.46875, 'x[8] <= 250.5\ngini = 0.609\nsamples = 24\nvalue = [0, 1, 20, 11, 2, 0, 0, 3, 0]'),
#  Text(0.6545454545454545, 0.40625, 'x[8] <= 219.0\ngini = 0.254\nsamples = 14\nvalue = [0, 1, 18, 0, 2, 0, 0, 0, 0]'),
#  Text(0.6363636363636364, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 2, 0, 0, 0, 0]'),
#  Text(0.6727272727272727, 0.34375, 'x[2] <= 7.015\ngini = 0.1\nsamples = 13\nvalue = [0, 1, 18, 0, 0, 0, 0, 0, 0]'),
#  Text(0.6545454545454545, 0.28125, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 18, 0, 0, 0, 0, 0, 0]'),
#  Text(0.6909090909090909, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0, 0, 0]'),
#  Text(0.7636363636363637, 0.40625, 'x[2] <= 5.77\ngini = 0.477\nsamples = 10\nvalue = [0, 0, 2, 11, 0, 0, 0, 3, 0]'),
#  Text(0.7454545454545455, 0.34375, 'x[10] <= 371.345\ngini = 0.48\nsamples = 3\nvalue = [0, 0, 2, 0, 0, 0, 0, 3, 0]'),
#  Text(0.7272727272727273, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0, 0, 0, 0, 0]'),
#  Text(0.7636363636363637, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 0, 3, 0]'),
#  Text(0.7818181818181819, 0.34375, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 11, 0, 0, 0, 0, 0]'),
#  Text(0.6204545454545455, 0.53125, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 0, 11, 0, 0, 0, 0]'),
#  Text(0.7818181818181819, 0.59375, 'x[4] <= 0.534\ngini = 0.245\nsamples = 23\nvalue = [0, 0, 0, 4, 31, 0, 0, 1, 0]'),
#  Text(0.7636363636363637, 0.53125, 'x[5] <= 7.339\ngini = 0.061\nsamples = 21\nvalue = [0, 0, 0, 0, 31, 0, 0, 1, 0]'),
#  Text(0.7454545454545455, 0.46875, 'gini = 0.0\nsamples = 20\nvalue = [0, 0, 0, 0, 31, 0, 0, 0, 0]'),
#  Text(0.7818181818181819, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.8, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 4, 0, 0, 0, 0, 0]'),
#  Text(0.8363636363636363, 0.65625, 'x[2] <= 7.17\ngini = 0.461\nsamples = 17\nvalue = [0, 0, 0, 16, 0, 0, 0, 9, 0]'),
#  Text(0.8181818181818182, 0.59375, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 0, 0, 0, 9, 0]'),
#  Text(0.8545454545454545, 0.59375, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 16, 0, 0, 0, 0, 0]'),
#  Text(0.5071022727272727, 0.78125, 'gini = 0.0\nsamples = 22\nvalue = [0, 0, 0, 0, 36, 0, 0, 0, 0]'),
#  Text(0.9090909090909091, 0.84375, 'x[0] <= 0.035\ngini = 0.403\nsamples = 19\nvalue = [1, 0, 0, 21, 0, 5, 0, 0, 1]'),
#  Text(0.8909090909090909, 0.78125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0, 0, 0]'),
#  Text(0.9272727272727272, 0.78125, 'x[9] <= 18.05\ngini = 0.359\nsamples = 18\nvalue = [0, 0, 0, 21, 0, 5, 0, 0, 1]'),
#  Text(0.8909090909090909, 0.71875, 'x[2] <= 6.625\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 0, 5, 0, 5, 0, 0, 0]'),
#  Text(0.8727272727272727, 0.65625, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 5, 0, 0, 0, 0, 0]'),
#  Text(0.9090909090909091, 0.65625, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 0, 5, 0, 0, 0]'),
#  Text(0.9636363636363636, 0.71875, 'x[6] <= 61.9\ngini = 0.111\nsamples = 10\nvalue = [0, 0, 0, 16, 0, 0, 0, 0, 1]'),
#  Text(0.9454545454545454, 0.65625, 'x[11] <= 7.955\ngini = 0.32\nsamples = 2\nvalue = [0, 0, 0, 4, 0, 0, 0, 0, 1]'),
#  Text(0.9272727272727272, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 4, 0, 0, 0, 0, 0]'),
#  Text(0.9636363636363636, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.9818181818181818, 0.65625, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 12, 0, 0, 0, 0, 0]'),
#  Text(0.7353693181818182, 0.90625, 'gini = 0.0\nsamples = 56\nvalue = [0, 0, 0, 0, 0, 0, 0, 0, 100]')]
