# %% [markdown]
# <a href="https://colab.research.google.com/github/t-abs/Machine-Learning/blob/main/RedWinedecisiontree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/archive (20).zip")

# %%
data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# Splitting the dataset

# %%
x=data.drop(columns='quality',axis=1)
y=data['quality']

# %%
x.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=      train_test_split(x,y)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([5, 6, 7, 5, 6, 7, 7, 6, 7, 5, 5, 5, 7, 5, 6, 6, 5, 6, 6, 8, 5, 5,
#        5, 5, 6, 5, 7, 5, 6, 7, 6, 5, 6, 5, 6, 5, 7, 6, 5, 7, 6, 6, 6, 6,
#        5, 6, 6, 6, 6, 6, 6, 6, 5, 5, 6, 6, 5, 5, 7, 7, 6, 7, 6, 6, 6, 6,
#        6, 7, 5, 5, 4, 6, 5, 6, 5, 5, 5, 5, 5, 5, 5, 5, 6, 5, 5, 5, 7, 5,
#        6, 8, 5, 6, 6, 7, 4, 5, 5, 5, 5, 5, 5, 6, 5, 5, 6, 6, 6, 5, 6, 5,
#        5, 6, 5, 7, 5, 5, 5, 5, 6, 7, 6, 5, 5, 6, 6, 4, 4, 5, 6, 7, 6, 5,
#        5, 5, 4, 6, 5, 6, 5, 5, 7, 6, 5, 6, 6, 7, 6, 5, 6, 6, 5, 7, 6, 5,
#        6, 6, 5, 6, 7, 5, 6, 7, 6, 5, 6, 6, 4, 6, 5, 5, 6, 6, 5, 5, 6, 7,
#        7, 6, 5, 5, 5, 4, 6, 6, 6, 5, 5, 5, 6, 5, 5, 5, 6, 7, 5, 5, 5, 6,
#        6, 6, 4, 6, 5, 6, 5, 5, 6, 6, 5, 6, 5, 5, 5, 5, 7, 6, 7, 6, 5, 6,
#        6, 6, 7, 6, 5, 5, 7, 6, 6, 5, 5, 6, 6, 6, 5, 8, 7, 6, 6, 6, 6, 7,
#        5, 5, 5, 5, 4, 6, 6, 5, 6, 6, 6, 6, 7, 6, 5, 5, 6, 6, 7, 5, 6, 5,
#        7, 4, 6, 6, 5, 6, 6, 5, 6, 6, 7, 7, 7, 7, 5, 6, 6, 6, 5, 5, 6, 5,
# ...

# %%
from sklearn import tree
plt.figure(figsize=(20, 20))
tree.plot_tree(model, filled=True)
# Out:
# [Text(0.4748475982212666, 0.9705882352941176, 'x[10] <= 10.15\ngini = 0.646\nsamples = 1199\nvalue = [8, 42, 511, 473, 150, 15]'),
#  Text(0.2054461493354183, 0.9117647058823529, 'x[9] <= 0.585\ngini = 0.515\nsamples = 607\nvalue = [4, 22, 381, 181, 17, 2]'),
#  Text(0.0946051602814699, 0.8529411764705882, 'x[4] <= 0.08\ngini = 0.389\nsamples = 288\nvalue = [2, 12, 218, 55, 1, 0]'),
#  Text(0.04652071931196247, 0.7941176470588235, 'x[0] <= 7.65\ngini = 0.475\nsamples = 137\nvalue = [2, 5, 92, 37, 1, 0]'),
#  Text(0.020328381548084442, 0.7352941176470589, 'x[1] <= 0.455\ngini = 0.323\nsamples = 62\nvalue = [1, 1, 50, 10, 0, 0]'),
#  Text(0.012509773260359656, 0.6764705882352942, 'x[9] <= 0.555\ngini = 0.568\nsamples = 13\nvalue = [0, 1, 6, 6, 0, 0]'),
#  Text(0.009382329945269743, 0.6176470588235294, 'x[4] <= 0.068\ngini = 0.406\nsamples = 8\nvalue = [0, 1, 1, 6, 0, 0]'),
# ...

# %% [markdown]
# 20 samples data

# %%
sampledata=data.head(20)

# %%
sampledata
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
x_sample=sampledata.drop(columns='quality',axis=1)
y_sample=sampledata['quality']

# %%
newmodel=DecisionTreeClassifier()
newmodel.fit(x_sample,y_sample)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
plt.figure(figsize=(20, 20))
tree.plot_tree(newmodel, filled=True)
# Out:
# [Text(0.5, 0.875, 'x[2] <= 0.435\ngini = 0.475\nsamples = 20\nvalue = [1, 14, 2, 3]'),
#  Text(0.25, 0.625, 'x[6] <= 25.0\ngini = 0.304\nsamples = 17\nvalue = [1, 14, 0, 2]'),
#  Text(0.125, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.375, 0.375, 'x[5] <= 7.5\ngini = 0.124\nsamples = 15\nvalue = [1, 14, 0, 0]'),
#  Text(0.25, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 14\nvalue = [0, 14, 0, 0]'),
#  Text(0.75, 0.625, 'x[5] <= 26.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1]'),
#  Text(0.625, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.875, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]')]
